# %%
def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# Define different complexities with practical algorithm examples
def constant_time(n):
    return np.ones_like(n)  # Example: Accessing an element in an array

def logarithmic_time(n):
    return np.log2(n)  # Example: Binary search

def linear_time(n):
    return n  # Example: Finding the maximum element in an array

def quadratic_time(n):
    return n ** 2  # Example: Bubble sort, selection sort

def cubic_time(n):
    return n ** 3  # Example: Floyd-Warshall algorithm (all pairs shortest paths)

def exponential_time(n):
    return 2 ** n  # Example: Solving the traveling salesman problem with brute force

def factorial_time(n):
    return np.array([np.math.factorial(i) for i in n], dtype=np.float64)  # Example: Generating all permutations of a set

# %%
# Generate input sizes
n_values = np.linspace(1, 10, 10, dtype=int)

# Compute complexity functions
y_values = {
    "O(1)": constant_time(n_values),
    "O(log n)": logarithmic_time(n_values),
    "O(n)": linear_time(n_values),
    "O(n^2)": quadratic_time(n_values),
    "O(n^3)": cubic_time(n_values),
    "O(2^n)": exponential_time(n_values),
     "O(n!) (Factorial Growth)": factorial_time(n_values)
}

# Define different line styles and markers for better differentiation
line_styles = ['-', '--', '-.', ':', '-', '--']
markers = ['o', 's', 'D', '^', 'v', 'p']
colors = ['b', 'g', 'r', 'c', 'm', 'y']

# Plot complexities
plt.figure(figsize=(10, 6))
for idx, (label, y) in enumerate(y_values.items()):
    plt.plot(n_values, y, linestyle=line_styles[idx % len(line_styles)], marker=markers[idx % len(markers)],
             color=colors[idx % len(colors)], label=label)

plt.yscale("log")  # Use log scale for better visualization of large values
plt.xlabel("Input size n")
plt.ylabel("Operations (log scale)")
plt.title("Big O Complexity Growth")
plt.legend()
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()
# Out:
# <ipython-input-35-fdaf9d9df89e>:25: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   return np.array([np.math.factorial(i) for i in n], dtype=np.float64)  # Example: Generating all permutations of a set

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# Define different complexities with practical algorithm examples
def constant_time(arr, index):
    return arr[index]  # Example: Accessing an element in an array

def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1  # Example: Binary search

def find_max(arr):
    max_value = arr[0]
    for num in arr:
        if num > max_value:
            max_value = num
    return max_value  # Example: Finding the maximum element in an array

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr  # Example: Bubble sort

def floyd_warshall(graph):
    n = len(graph)
    dist = [[graph[i][j] for j in range(n)] for i in range(n)]
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dist[i][j] = min(dist[i][j], dist[i][k] + dist[k][j])
    return dist  # Example: Floyd-Warshall algorithm (all pairs shortest paths)

def tsp_brute_force(cities):
    from itertools import permutations
    min_path = float('inf')
    for perm in permutations(cities):
        cost = sum(abs(perm[i] - perm[i+1]) for i in range(len(perm)-1))
        min_path = min(min_path, cost)
    return min_path  # Example: Solving the traveling salesman problem with brute force

def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n-1)  # Example: Generating all permutations of a set

def factorial_time(n_values):
    return np.array([np.math.factorial(i) for i in n_values], dtype=np.float64)

# Generate input sizes
n_values = np.linspace(1, 10, 10, dtype=int)

# Compute complexity functions
y_values = {
    "O(1) (Array Access)": np.ones_like(n_values),
    "O(log n) (Binary Search)": np.log2(n_values),
    "O(n) (Max Element Search)": n_values,
    "O(n^2) (Bubble Sort)": n_values ** 2,
    "O(n^3) (Floyd-Warshall)": n_values ** 3,
    "O(2^n) (TSP Brute Force)": 2 ** n_values,
    "O(n!) (Factorial Growth)": factorial_time(n_values)
}

# Define different line styles and markers for better differentiation
line_styles = ['-', '--', '-.', ':', '-', '--', ':']
markers = ['o', 's', 'D', '^', 'v', 'p', '*']
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

# Plot complexities
plt.figure(figsize=(10, 6))
for idx, (label, y) in enumerate(y_values.items()):
    plt.plot(n_values, y, linestyle=line_styles[idx % len(line_styles)], marker=markers[idx % len(markers)],
             color=colors[idx % len(colors)], label=label)

plt.yscale("log")  # Use log scale for better visualization of large values
plt.xlabel("Input size n")
plt.ylabel("Operations (log scale)")
plt.title("Big O Complexity Growth with Algorithm Examples")
plt.legend()
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()
# Out:
# <ipython-input-41-f9aec60d1e0b>:59: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   return np.array([np.math.factorial(i) for i in n_values], dtype=np.float64)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from itertools import permutations

def constant_time(arr, index):
    return arr[index]

def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1

def find_max(arr):
    max_value = arr[0]
    for num in arr:
        if num > max_value:
            max_value = num
    return max_value

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

def floyd_warshall(graph):
    n = len(graph)
    dist = [[graph[i][j] for j in range(n)] for i in range(n)]
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dist[i][j] = min(dist[i][j], dist[i][k] + dist[k][j])
    return dist

def tsp_brute_force(cities):
    min_path = float('inf')
    for perm in permutations(cities):
        cost = sum(abs(perm[i] - perm[i + 1]) for i in range(len(perm) - 1))
        min_path = min(min_path, cost)
    return min_path

def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n - 1)

def measure_time(func, arr):
    start_time = time.time()
    func(arr)
    return time.time() - start_time

n_values = np.arange(1, 11)
arr_sizes = [np.random.randint(0, 100, n) for n in n_values]

y_values = {
    "O(1) (Array Access)": [measure_time(lambda arr: constant_time(arr, len(arr) // 2), arr) for arr in arr_sizes],
    "O(log n) (Binary Search)": [measure_time(lambda arr: binary_search(arr, arr[len(arr) // 2]), arr) for arr in arr_sizes],
    "O(n) (Max Element Search)": [measure_time(find_max, arr) for arr in arr_sizes],
    "O(n^2) (Bubble Sort)": [measure_time(bubble_sort, arr.tolist()) for arr in arr_sizes],
    "O(n^3) (Floyd-Warshall)": [measure_time(floyd_warshall, np.random.randint(1, 100, (len(arr), len(arr)))) for arr in arr_sizes],
    "O(2^n) (TSP Brute Force)": [measure_time(tsp_brute_force, list(range(len(arr)))) if len(arr) < 10 else None for arr in arr_sizes],
    "O(n!) (Factorial Growth)": [measure_time(factorial, len(arr)) if len(arr) < 10 else None for arr in arr_sizes]
}

plt.figure(figsize=(10, 6))
line_styles = ['-', '--', '-.', ':', '-', '--', ':']
markers = ['o', 's', 'D', '^', 'v', 'p', '*']
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

for idx, (label, y) in enumerate(y_values.items()):
    plt.plot(n_values, y, linestyle=line_styles[idx % len(line_styles)], marker=markers[idx % len(markers)],
             color=colors[idx % len(colors)], label=label)

plt.yscale("log")
plt.xlabel("Input size n")
plt.ylabel("Execution Time (log scale)")
plt.title("Big O Complexity Growth with Algorithm Examples")
plt.legend()
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()
